# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import scale
import sklearn.linear_model as skl_lm
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as spst

import seaborn as sns

# %%
pearson = pd.read_csv('credit.csv')

# %%
lm1 = smf.ols('Balance~Income', pearson).fit()
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Balance   R-squared:                       0.215
# Model:                            OLS   Adj. R-squared:                  0.213
# Method:                 Least Squares   F-statistic:                     109.0
# Date:                Fri, 15 Nov 2019   Prob (F-statistic):           1.03e-22
# Time:                        01:54:15   Log-Likelihood:                -2970.9
# No. Observations:                 400   AIC:                             5946.
# Df Residuals:                     398   BIC:                             5954.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    246.5148     33.199      7.425      0.000     181.247     311.783
# ...

# %%
lm2 = smf.ols('Balance ~ Limit', pearson).fit()
lm2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Balance   R-squared:                       0.743
# Model:                            OLS   Adj. R-squared:                  0.742
# Method:                 Least Squares   F-statistic:                     1148.
# Date:                Fri, 15 Nov 2019   Prob (F-statistic):          2.53e-119
# Time:                        02:34:31   Log-Likelihood:                -2748.0
# No. Observations:                 400   AIC:                             5500.
# Df Residuals:                     398   BIC:                             5508.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -292.7905     26.683    -10.973      0.000    -345.249    -240.332
# ...

# %%
lm3 = smf.ols('Balance ~ Rating', pearson).fit()
lm3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Balance   R-squared:                       0.746
# Model:                            OLS   Adj. R-squared:                  0.745
# Method:                 Least Squares   F-statistic:                     1168.
# Date:                Fri, 15 Nov 2019   Prob (F-statistic):          1.90e-120
# Time:                        02:35:13   Log-Likelihood:                -2745.4
# No. Observations:                 400   AIC:                             5495.
# Df Residuals:                     398   BIC:                             5503.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -390.8463     29.069    -13.446      0.000    -447.993    -333.699
# ...

# %%
lm = smf.ols('Balance ~ Age + Ethnicity + Education + Student + Married', pearson).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Balance   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.055
# Method:                 Least Squares   F-statistic:                     4.840
# Date:                Fri, 15 Nov 2019   Prob (F-statistic):           8.77e-05
# Time:                        02:36:29   Log-Likelihood:                -3005.1
# No. Observations:                 400   AIC:                             6024.
# Df Residuals:                     393   BIC:                             6052.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...
